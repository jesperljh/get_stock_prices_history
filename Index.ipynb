# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/74/f8/cdfaf864e77b9f8a7688b07a3b990321e56b30bb316d7d241f584f330cd1/yfinance-0.1.43.tar.gz
# Requirement already satisfied: pandas>=0.24 in /srv/conda/lib/python3.6/site-packages (from yfinance) (0.24.2)
# Requirement already satisfied: numpy>=1.15 in /srv/conda/lib/python3.6/site-packages (from yfinance) (1.16.3)
# Requirement already satisfied: requests>=2.20 in /srv/conda/lib/python3.6/site-packages (from yfinance) (2.21.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading https://files.pythonhosted.org/packages/69/e7/e9f1661c28f7b87abfa08cb0e8f51dad2240a9f4f741f02ea839835e6d18/multitasking-0.0.9.tar.gz
# Requirement already satisfied: pytz>=2011k in /srv/conda/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /srv/conda/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/conda/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /srv/conda/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /srv/conda/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2019.3.9)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.24->yfinance) (1.12.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e8/9b/5a/a0dc81508455c34afcf2833513c3b9de3f39662d9ee2f92612
#   Building wheel for multitasking (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/37/fa/73/d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.43
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
print(msft)
# Out:
# Ticker object <MSFT>

# %%
# get stock info
msft.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'currency': 'USD',
#  'market': 'us_market',
#  'exchangeDataDelayedBy': 0,
#  'marketState': 'REGULAR',
#  'esgPopulated': False,
#  'tradeable': True,
#  'marketCap': 1045438464000,
#  'fiftyDayAverageChangePercent': 0.06087692,
#  'twoHundredDayAverage': 115.96824,
#  'twoHundredDayAverageChange': 20.461754,
#  'twoHundredDayAverageChangePercent': 0.17644274,
#  'forwardPE': 26.698627,
#  'priceHint': 2,
#  'fiftyTwoWeekHighChange': -1.9700012,
#  'regularMarketChangePercent': -0.97982734,
#  'regularMarketDayRange': '136.06 - 137.58',
#  'regularMarketPreviousClose': 137.78,
#  'bid': 136.66,
#  'ask': 136.67,
#  'bidSize': 13,
#  'askSize': 11,
#  'messageBoardId': 'finmb_21835',
#  'fullExchangeName': 'NasdaqGS',
#  'longName': 'Microsoft Corporation',
#  'financialCurrency': 'USD',
#  'averageDailyVolume3Month': 23511539,
#  'averageDailyVolume10Day': 25764416,
#  'fiftyTwoWeekLowChange': 42.469994,
#  'fiftyTwoWeekLowChangePercent': 0.4520008,
#  'fiftyTwoWeekRange': '93.96 - 138.4',
#  'fiftyTwoWeekHighChangePercent': -0.0142341135,
#  'fiftyTwoWeekLow': 93.96,
#  'fiftyTwoWeekHigh': 138.4,
#  'dividendDate': 1568246400,
#  'earningsTimestamp': 1556136000,
#  'earningsTimestampStart': 1563361140,
#  'earningsTimestampEnd': 1563796800,
#  'trailingAnnualDividendRate': 1.8,
#  'trailingPE': 30.31104,
#  'trailingAnnualDividendYield': 0.013064305,
#  'epsTrailingTwelveMonths': 4.501,
#  'epsForward': 5.11,
#  'sharesOutstanding': 7662819840,
#  'bookValue': 12.375,
#  'fiftyDayAverage': 128.60115,
#  'exchange': 'NMS',
#  'fiftyDayAverageChange': 7.828842,
#  'priceToBook': 11.024646,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'regularMarketPrice': 136.43,
#  'regularMarketTime': 1561470902,
#  'regularMarketChange': -1.3500061,
#  'regularMarketOpen': 137.25,
#  'regularMarketDayHigh': 137.58,
#  'regularMarketDayLow': 136.06,
#  'regularMarketVolume': 3260699,
#  'shortName': 'Microsoft Corporation',
#  'symbol': 'MSFT'}

# %%
# get historical market data
msft.history(period="max")
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.07  1031788800       0.00
# 1986-03-14    0.07    0.07    0.07    0.07   308160000       0.00
# 1986-03-17    0.07    0.07    0.07    0.07   133171200       0.00
# 1986-03-18    0.07    0.07    0.07    0.07    67766400       0.00
# 1986-03-19    0.07    0.07    0.07    0.07    47894400       0.00
# 1986-03-20    0.07    0.07    0.07    0.07    58435200       0.00
# 1986-03-21    0.07    0.07    0.07    0.07    59990400       0.00
# 1986-03-24    0.07    0.07    0.06    0.06    65289600       0.00
# 1986-03-25    0.06    0.07    0.06    0.07    32083200       0.00
# 1986-03-26    0.07    0.07    0.07    0.07    22752000       0.00
# 1986-03-27    0.07    0.07    0.07    0.07    16848000       0.00
# 2014-08-19       0.28           0.0
# 2014-11-18       0.31           0.0
# 2015-02-17       0.31           0.0
# 2015-05-19       0.31           0.0
# 2015-08-18       0.31           0.0
# 2015-11-17       0.36           0.0
# 2016-02-16       0.36           0.0
# 2016-05-17       0.36           0.0
# 2016-08-16       0.36           0.0
# 2016-11-15       0.39           0.0
# 2017-02-14       0.39           0.0
# 2017-05-16       0.39           0.0
# 2017-08-15       0.39           0.0
# 2017-11-15       0.42           0.0
# 2018-02-14       0.42           0.0
# 2018-05-16       0.42           0.0
# 2018-08-15       0.42           0.0
# 2018-11-14       0.46           0.0
# 2019-02-20       0.46           0.0
# 2019-05-15       0.46           0.0
#
# [71 rows x 2 columns]

# %%
# show dividends
msft.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    0.08
# 2005-02-15    0.08
# 2005-05-16    0.08
# 2005-08-15    0.08
# 2005-11-15    0.08
# 2006-02-15    0.09
# 2006-05-15    0.09
# 2006-08-15    0.09
# 2006-11-14    0.10
# 2007-02-13    0.10
# 2007-05-15    0.10
# 2007-08-14    0.10
# 2007-11-13    0.11
# 2008-02-19    0.11
# 2008-05-13    0.11
# 2008-08-19    0.11
# 2008-11-18    0.13
# 2009-02-17    0.13
# 2009-05-19    0.13
# 2009-08-18    0.13
# 2009-11-17    0.13
# 2010-02-16    0.13
# 2010-05-18    0.13
# 2010-08-17    0.13
# 2010-11-16    0.16
# 2011-02-15    0.16
# 2011-05-17    0.16
#               ...
# 2012-02-14    0.20
# 2012-05-15    0.20
# 2012-08-14    0.20
# 2012-11-13    0.23
# 2013-02-19    0.23
# 2013-05-14    0.23
# 2013-08-13    0.23
# 2013-11-19    0.28
# 2014-02-18    0.28
# 2014-05-13    0.28
# 2014-08-19    0.28
# 2014-11-18    0.31
# 2015-02-17    0.31
# 2015-05-19    0.31
# 2015-08-18    0.31
# 2015-11-17    0.36
# 2016-02-16    0.36
# 2016-05-17    0.36
# 2016-08-16    0.36
# 2016-11-15    0.39
# 2017-02-14    0.39
# 2017-05-16    0.39
# 2017-08-15    0.39
# 2017-11-15    0.42
# 2018-02-14    0.42
# 2018-05-16    0.42
# 2018-08-15    0.42
# 2018-11-14    0.46
# 2019-02-20    0.46
# 2019-05-15    0.46
# Name: Dividends, Length: 62, dtype: float64

# %%
# show splits
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64

# %%
from IPython.display import HTML
import base64  
import pandas as pd  

def create_download_link( df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(msft.history(period="max"))
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
